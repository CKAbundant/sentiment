# %% [markdown]
# # Seeking Alpha
#
# JJ appears to scrape following webpage in SeekingAlpha based on his `enter.js` file:
#
# - https://seekingalpha.com/alpha-picks/picks/current
# - https://seekingalpha.com/alpha-picks/picks/removed

# %%
from scrapling import Fetcher, StealthyFetcher, PlayWrightFetcher
from dotenv import load_dotenv
import os
import re
from pprint import pformat

# %load_ext autoreload
# %autoreload 2

from src.utils.init_script_utils import append_mimetypes

load_dotenv()
cur_url = "https://seekingalpha.com/alpha-picks/picks/current"
rm_url = "https://seekingalpha.com/alpha-picks/picks/removed"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
<div aria-labelledby="auth-modal-label" aria-modal="true"
    class="w-full KRkzG pointer-events-auto relative mx-auto my-0 flex flex-col bg-share-modal-container mpcDT w-full md:max-w-full md:w-auto px-18"
    data-test-id="modal-content">
    <div class="wZqjb mx-auto w-full flex-auto overflow-y-auto md:max-w-none md:overflow-y-hidden">
        <div class="relative px-18 pb-20 pt-0 text-center md:px-52 md:pb-28">
            <form novalidate="">
        </div><button
            class="relative inline-flex cursor-pointer select-none items-center whitespace-nowrap break-words transition-colors hover:no-underline motion-reduce:transition-none rounded-4 border-black bg-black text-white hover:bg-black-70 disabled:border-transparent disabled:bg-black-20 dark:border-black-10 dark:bg-black-10 dark:text-black dark:hover:border-black-10 dark:hover:bg-black-10 dark:disabled:bg-black-30 w-full md:min-h-36 md:justify-center md:border md:px-16 md:py-1 md:text-medium-b min-h-44 justify-center border px-18 py-1 text-medium-b"
            data-test-id="sign-in-button" type="submit"><span class="">Sign in</span></button>
        </form>
    </div>
</div>
</div>

# %% [markdown]
# # Scrapling
#
# - Fetcher is able to perform GET request for different sections of market news in seekingalpha.com.
# - Unfortunately Scrapling (i.e. Fetcher, StealthyFetcher, PlaywrightFetcher) is not able to scrape from `cur_url` and `rm_url` as login is required.

# %% [markdown]
# ## Fetcher

# %%
fetcher = Fetcher(auto_match=False)

page = fetcher.post(cur_url, email=os.getenv("COY_EMAIL"), password="COY_PASSWORD")
print(page.get_all_text())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 fetcher = Fetcher(auto_match=False)
# ----> 3 page = fetcher.post(cur_url, email=os.getenv("COY_EMAIL"), password="COY_PASSWORD")
#       4 print(page.get_all_text())
#
# File ~/miniconda3/envs/web/lib/python3.13/site-packages/scrapling/fetchers.py:48, in Fetcher.post(self, url, follow_redirects, timeout, stealthy_headers, proxy, retries, **kwargs)
#      35 """Make basic HTTP POST request for you but with some added flavors.
#      36
#      37 :param url: Target url.
#    (...)     45 :return: A `Response` object that is the same as `Adaptor` object except it has these added attributes: `status`, `reason`, `cookies`, `headers`, and `request_headers`
#      46 """
#      47 adaptor_arguments = tuple(self.adaptor_arguments.items())
# ...

# %% [markdown]
# ## StealthyFetcher

# %%
stealthyfetcher = StealthyFetcher()
page = await stealthyfetcher.async_fetch(
    cur_url,
    extra_headers={
        "email": os.getenv("COY_EMAIL"),
        "password": os.getenv("COY_PASSWORD"),
    },
)
print(page.get_all_text())
# Out:
# [2025-03-17 10:33:06] INFO: Fetched (308) <GET https://seekingalpha.com/alpha-picks/picks/current> (referer: https://www.google.com/search?q=seekingalpha)
# [2025-03-17 10:33:06] INFO: Fetched (200) <GET https://seekingalpha.com/alpha-picks/subscribe> (referer: https://www.google.com/)
# Alpha Picks by Seeking Alpha, Choose 2 Stocks Per Month | Seeking Alpha

# %% [markdown]
# ## PlaywrightFetcher

# %%
playwrightfetcher = PlayWrightFetcher()
page = await playwrightfetcher.async_fetch(
    cur_url,
    extra_headers={
        "email": os.getenv("COY_EMAIL"),
        "password": os.getenv("COY_PASSWORD"),
    },
)
print(page.get_all_text())
# Out:
# [2025-03-17 10:35:01] INFO: Fetched (308) <GET https://seekingalpha.com/alpha-picks/picks/current> (referer: https://www.google.com/search?q=seekingalpha)
# [2025-03-17 10:35:01] INFO: Fetched (200) <GET https://seekingalpha.com/alpha-picks/subscribe> (referer: https://www.google.com/)
# Alpha Picks by Seeking Alpha, Choose 2 Stocks Per Month | Seeking Alpha

# %% [markdown]
# # Selenium
#
# - https://stackoverflow.com/questions/53039551/selenium-webdriver-modifying-navigator-webdriver-flag-to-prevent-selenium-detec

# %% [markdown]
# # Playwright

# %% [markdown]
# | Issue                                                                                    | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | ---------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Firefox trigger bot detection                                                            | &bull; It creates popup window (i.e. iframe) to request login via Google (both in head and headless mode). <br>&bull; Then trigger bot detection i.e. request user to 'press and hold' on button.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | chromium trigger bot detection                                                           | &bull; When accessing the webpage directly bypassing 'subscribe' page. <br>&bull; Bot detection occasionally triggered When repeating launching webscraper.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | chromium couldn't redirect                                                               | &bull; When clicking on 'Sign in' button after filling up 'email' and 'password', button is visually clicked and loading window visual (orange light) is visible. <br>&bull; But no redirect from "https://seekingalpha.com/alpha-picks/subscribe" to"https://seekingalpha.com/alpha-picks/picks/current" occurs. <br>&bull; If 'page.wait_for_load_state("networkidle") is added after the click function, it will trigger bot detection; and TimeoutError, which implies that network was still active even after 30 seconds. <br>&bull; Changing the channel from default chromium to chrome doesn't resolve the issue.                                                                                                                                                                                                                                                                         |
# | Using Javascript to submit the form closes the 'login' window but url wasn't redirected. | <br>&bull; Address path: "https://seekingalpha.com/alpha-picks/subscribe?email=limjj11%40hotmail.com&password=v2%26B%40l%40xV" suggest that a GET request is send to the server but wasn't successful with and without networkidle. <br>&bull; Use of JavaScript to submit form didn't trigger bot detection despite setting wait for networkidle.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | Manual goto required URL trigger bot detection                                           | &bull; networkidle + JavaScript + wait_for_url -> trigger bot detection. <br>&bull; networkidle + JavaScript + no wait_for_url -> TimeoutError or trigger bot detection. <br>&bull; No networkidle + JavaScript + wait_for_url -> Error: Page.goto: net::ERR_ABORTED at https://seekingalpha.com/alpha-picks/picks/current <br>&bull; No networkidle + JavaScript + no wait_for_url -> Error: Page.goto: net::ERR_ABORTED at https://seekingalpha.com/alpha-picks/picks/current <br>&bull; networkidle + click + wait_for_url -> trigger bot detection <br>&bull; networkidle + click + no wait_for_url -> TimeoutError + trigger bot detection. <br>&bull; No networkidle + click + wait_for_url -> TimeoutError or trigger bot detection (sometimes no error but no redirect). <br>&bull; No networkidle + click + no wait_for_url -> trigger bot detection (sometimes no error but no redirect) |
# | Playwright stealth doesn't work                                                          | &bull; Automatically trigger bot detection page without accessing 'subscribe' page.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |

# %% [raw]
# (web) ckabundant@HP-Laptop:~/Documents/sentiment$ python src/scraper.py
# >> GET https://seekingalpha.com/alpha-picks/subscribe
# << 200 https://seekingalpha.com/alpha-picks/subscribe
# >> GET https://seekingalpha.com/api/v3/breaking_news
# >> GET https://seekingalpha.com/api/v3/market_open
# >> GET https://seekingalpha.com/api/v3/piano_tag_for_url_params
# >> GET https://seekingalpha.com/api/v3/ab_tests
# >> GET https://seekingalpha.com/samw/static/js/c.68154.a92438f6.js
# >> GET https://seekingalpha.com/samw/static/js/c.98406.a523caba.js
# >> GET https://seekingalpha.com/samw/static/js/c.3296.b5deb7f7.js
# >> GET https://seekingalpha.com/samw/static/js/c.65006.ef6465ed.js
# >> GET https://seekingalpha.com/samw/static/js/c.89098.ef36a800.js
# >> GET https://seekingalpha.com/samw/static/js/c.91585.954c710b.js
# >> GET https://seekingalpha.com/samw/static/js/c.14142.91883302.js
# >> GET https://seekingalpha.com/samw/static/js/c.36192.ff9b0433.js
# >> GET https://seekingalpha.com/samw/static/js/c.65848.cdbda4d5.js
# >> GET https://seekingalpha.com/samw/static/js/c.77824.cca24e61.js
# >> GET https://seekingalpha.com/samw/static/js/c.28742.2fc0622a.js
# >> GET https://seekingalpha.com/samw/static/js/c.62432.55ea12cd.js
# >> GET https://seekingalpha.com/samw/static/js/c.20233.578075aa.js
# >> GET https://seekingalpha.com/samw/static/js/c.63656.d9877cd2.js
# >> GET https://seekingalpha.com/samw/static/js/c.20441.70eec58e.js
# >> GET https://seekingalpha.com/samw/static/js/c.20232.97f51073.js
# >> GET https://seekingalpha.com/samw/static/js/c.89494.b364b562.js
# >> GET https://seekingalpha.com/samw/static/js/c.26966.12a45ab1.js
# >> GET https://seekingalpha.com/samw/static/js/c.43264.295520f0.js
# >> GET https://seekingalpha.com/samw/static/js/c.23870.07360387.js
# >> GET https://seekingalpha.com/samw/static/js/c.56247.264eca14.js
# >> GET https://seekingalpha.com/samw/static/js/c.15148.42fb2892.js
# >> GET https://seekingalpha.com/samw/static/js/c.31797.4d1eb26c.js
# >> GET https://seekingalpha.com/samw/static/js/c.21980.9c29671d.js
# >> GET https://seekingalpha.com/samw/static/js/c.48010.e31b27b1.js
# >> GET https://seekingalpha.com/samw/static/js/c.10191.fb198f57.js
# >> GET https://seekingalpha.com/samw/static/js/c.9430.83405307.js
# >> GET https://seekingalpha.com/samw/static/js/c.81356.86d5eaba.js
# >> GET https://seekingalpha.com/samw/static/js/c.81266.f96e8c1b.js
# >> GET https://seekingalpha.com/samw/static/js/c.5475.dababb34.js
# >> GET https://seekingalpha.com/samw/static/js/c.94306.bfdd229d.js
# >> GET https://seekingalpha.com/samw/static/js/c.AlphaPicks-S.6fad2579.js
# >> GET https://seekingalpha.com/samw/static/styles/AlphaPicks-S.7531225e.css
# << 200 https://seekingalpha.com/api/v3/piano_tag_for_url_params
# << 200 https://seekingalpha.com/api/v3/breaking_news
# << 200 https://seekingalpha.com/api/v3/ab_tests
# << 200 https://seekingalpha.com/api/v3/market_open
# << 200 https://seekingalpha.com/samw/static/js/c.68154.a92438f6.js
# << 200 https://seekingalpha.com/samw/static/js/c.98406.a523caba.js
# << 200 https://seekingalpha.com/samw/static/js/c.3296.b5deb7f7.js
# >> GET https://seekingalpha.com/samw/static/js/runtime-chunk.a965dfc7.js
# >> GET https://seekingalpha.com/samw/static/js/app.dbe131a7.js
# << 200 https://seekingalpha.com/samw/static/styles/AlphaPicks-S.7531225e.css
# << 200 https://seekingalpha.com/samw/static/js/c.89098.ef36a800.js
# << 200 https://seekingalpha.com/samw/static/js/c.65006.ef6465ed.js
# << 200 https://seekingalpha.com/samw/static/js/c.91585.954c710b.js
# << 200 https://seekingalpha.com/samw/static/js/c.14142.91883302.js
# << 200 https://seekingalpha.com/samw/static/js/c.36192.ff9b0433.js
# << 200 https://seekingalpha.com/samw/static/js/c.77824.cca24e61.js
# << 200 https://seekingalpha.com/samw/static/js/c.62432.55ea12cd.js
# << 200 https://seekingalpha.com/samw/static/js/c.28742.2fc0622a.js
# << 200 https://seekingalpha.com/samw/static/js/c.65848.cdbda4d5.js
# << 200 https://seekingalpha.com/samw/static/js/c.20233.578075aa.js
# << 200 https://seekingalpha.com/samw/static/js/c.63656.d9877cd2.js
# << 200 https://seekingalpha.com/samw/static/js/c.20441.70eec58e.js
# << 200 https://seekingalpha.com/samw/static/js/c.20232.97f51073.js
# << 200 https://seekingalpha.com/samw/static/js/c.89494.b364b562.js
# << 200 https://seekingalpha.com/samw/static/js/c.26966.12a45ab1.js
# << 200 https://seekingalpha.com/samw/static/js/c.43264.295520f0.js
# << 200 https://seekingalpha.com/samw/static/js/c.56247.264eca14.js
# << 200 https://seekingalpha.com/samw/static/js/c.23870.07360387.js
# << 200 https://seekingalpha.com/samw/static/js/c.15148.42fb2892.js
# << 200 https://seekingalpha.com/samw/static/js/c.31797.4d1eb26c.js
# << 200 https://seekingalpha.com/samw/static/js/c.21980.9c29671d.js
# << 200 https://seekingalpha.com/samw/static/js/c.48010.e31b27b1.js
# << 200 https://seekingalpha.com/samw/static/js/c.10191.fb198f57.js
# << 200 https://seekingalpha.com/samw/static/js/c.9430.83405307.js
# << 200 https://seekingalpha.com/samw/static/js/c.81356.86d5eaba.js
# << 200 https://seekingalpha.com/samw/static/js/c.81266.f96e8c1b.js
# << 200 https://seekingalpha.com/samw/static/js/c.5475.dababb34.js
# << 200 https://seekingalpha.com/samw/static/js/c.94306.bfdd229d.js
# << 200 https://seekingalpha.com/samw/static/js/runtime-chunk.a965dfc7.js
# << 200 https://seekingalpha.com/samw/static/js/c.AlphaPicks-S.6fad2579.js
# << 200 https://seekingalpha.com/samw/static/js/app.dbe131a7.js
# >> POST https://seekingalpha.com/mone_v2
# >> GET https://seekingalpha.com/samw/static/styles/8150.31d6cfe0.css
# >> GET https://seekingalpha.com/samw/static/js/c.15247.67e00ebb.js
# >> GET https://seekingalpha.com/samw/static/js/c.34228.604d50a8.js
# >> GET https://seekingalpha.com/samw/static/js/c.70839.656a1537.js
# >> GET https://seekingalpha.com/samw/static/js/c.75002.bded6459.js
# >> GET https://seekingalpha.com/samw/static/js/c.91858.130502c0.js
# >> GET https://seekingalpha.com/samw/static/styles/Layout-W.799dd967.css
# << 200 https://seekingalpha.com/samw/static/styles/8150.31d6cfe0.css
# << 200 https://seekingalpha.com/samw/static/styles/Layout-W.799dd967.css
# << 200 https://seekingalpha.com/samw/static/js/c.34228.604d50a8.js
# << 200 https://seekingalpha.com/samw/static/js/c.70839.656a1537.js
# << 200 https://seekingalpha.com/samw/static/js/c.15247.67e00ebb.js
# << 200 https://seekingalpha.com/samw/static/js/c.75002.bded6459.js
# << 200 https://seekingalpha.com/samw/static/js/c.91858.130502c0.js
# >> GET https://seekingalpha.com/samw/static/styles/17121.2a31a0c9.css
# >> GET https://seekingalpha.com/samw/static/js/c.17121.079006d9.js
# >> GET https://seekingalpha.com/samw/static/styles/MCMNavbarMenuItemContainer-W.9b812a6d.css
# >> GET https://seekingalpha.com/samw/static/js/c.MCMNavbarMenuItemContainer-W.63ab31ee.js
# << 200 https://seekingalpha.com/samw/static/styles/17121.2a31a0c9.css
# << 200 https://seekingalpha.com/samw/static/styles/MCMNavbarMenuItemContainer-W.9b812a6d.css
# << 200 https://seekingalpha.com/samw/static/js/c.17121.079006d9.js
# << 200 https://seekingalpha.com/samw/static/js/c.MCMNavbarMenuItemContainer-W.63ab31ee.js
# >> GET https://seekingalpha.com/samw/static/js/c.MCMStickyBottomCampaignsAsync-W.038183fe.js
# >> GET https://seekingalpha.com/samw/static/js/c.GoogleOneTap-W.607c6a04.js
# >> GET https://seekingalpha.com/samw/static/js/c.66477.27a3834b.js
# >> GET https://seekingalpha.com/samw/static/styles/Footer-W.f7512adc.css
# << 200 https://seekingalpha.com/samw/static/styles/Footer-W.f7512adc.css
# << 200 https://seekingalpha.com/samw/static/js/c.MCMStickyBottomCampaignsAsync-W.038183fe.js
# << 200 https://seekingalpha.com/samw/static/js/c.GoogleOneTap-W.607c6a04.js
# << 200 https://seekingalpha.com/samw/static/js/c.66477.27a3834b.js
# >> GET https://fonts.googleapis.com/css2?family=Lato:ital,wght@0,400;0,700;1,400;1,900&display=swap
# >> GET https://accounts.google.com/gsi/client
# << 200 https://seekingalpha.com/mone_v2
# >> GET https://seekingalpha.com/api/v3/marketplace/services/1409?include[]=author&include[]=author.user&include[]=contributor_bios&include[]=testimonials&include[]=plans&include[]=plans.prices
# >> GET https://seekingalpha.com/api/v3/backtest?backtest_type=alpha_picks
# << 200 https://fonts.googleapis.com/css2?family=Lato:ital,wght@0,400;0,700;1,400;1,900&display=swap
# << 200 https://seekingalpha.com/api/v3/marketplace/services/1409?include[]=author&include[]=author.user&include[]=contributor_bios&include[]=testimonials&include[]=plans&include[]=plans.prices
# << 200 https://seekingalpha.com/api/v3/backtest?backtest_type=alpha_picks
# >> GET https://seekingalpha.com/samw/static/js/c.46074.ce2ff92a.js
# >> GET https://seekingalpha.com/samw/static/js/c.97016.12499724.js
# >> GET https://seekingalpha.com/samw/static/js/c.22227.935b15f1.js
# >> GET https://seekingalpha.com/samw/static/js/c.11869.74378be9.js
# >> GET https://seekingalpha.com/samw/static/js/c.95251.ca2d00ae.js
# >> GET https://seekingalpha.com/samw/static/js/c.70453.a7b6cd4a.js
# >> GET https://seekingalpha.com/samw/static/js/c.31998.8dd032b0.js
# >> GET https://seekingalpha.com/samw/static/js/c.86448.a902d8f7.js
# >> GET https://seekingalpha.com/samw/static/js/c.96413.ba113d90.js
# >> GET https://seekingalpha.com/samw/static/styles/AlphaPicksCheckout-W.0b05c1be.css
# >> GET https://seekingalpha.com/samw/static/js/c.AlphaPicksCheckout-W.1dbd3ccb.js
# >> GET https://seekingalpha.com/samw/static/images/graphDesktopLight.0b34716f.png
# >> GET https://seekingalpha.com/api/v3/product_offers/mpb_1409
# >> POST https://seekingalpha.com/mone_v2
# >> GET https://seekingalpha.com/_sa_...
# << 200 https://seekingalpha.com/samw/static/styles/AlphaPicksCheckout-W.0b05c1be.css
# << 200 https://seekingalpha.com/samw/static/images/graphDesktopLight.0b34716f.png
# >> GET https://seekingalpha.com/samw/static/images/imageDesktop.79a781a8.png?io=auto
# << 200 https://seekingalpha.com/samw/static/js/c.11869.74378be9.js
# << 200 https://seekingalpha.com/samw/static/js/c.22227.935b15f1.js
# << 200 https://seekingalpha.com/samw/static/js/c.97016.12499724.js
# << 200 https://seekingalpha.com/samw/static/js/c.31998.8dd032b0.js
# << 200 https://seekingalpha.com/samw/static/js/c.86448.a902d8f7.js
# << 200 https://seekingalpha.com/samw/static/js/c.96413.ba113d90.js
# << 200 https://seekingalpha.com/samw/static/js/c.AlphaPicksCheckout-W.1dbd3ccb.js
# << 200 https://seekingalpha.com/samw/static/js/c.70453.a7b6cd4a.js
# << 200 https://seekingalpha.com/samw/static/js/c.46074.ce2ff92a.js
# << 200 https://seekingalpha.com/samw/static/js/c.95251.ca2d00ae.js
# << 200 https://accounts.google.com/gsi/client
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/mone_v2
# >> GET https://js.stripe.com/v3
# << 204 https://seekingalpha.com/_sa_...
# << 200 https://seekingalpha.com/samw/static/images/imageDesktop.79a781a8.png?io=auto
# >> GET https://accounts.google.com/gsi/style
# >> POST https://seekingalpha.com/mone_v2
# >> GET https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js
# >> GET https://connect.facebook.net/en_US/sdk.js
# >> GET https://seekingalpha.com/samw/static/js/c.35963.ee87d96c.js
# >> GET https://seekingalpha.com/samw/static/js/c.15589.e2154676.js
# >> GET https://seekingalpha.com/samw/static/js/c.71470.ee3a2642.js
# >> GET https://seekingalpha.com/samw/static/styles/AuthModal-W.ee0065ca.css
# >> GET https://seekingalpha.com/samw/static/js/c.AuthModal-W.d32afdb8.js
# << 200 https://accounts.google.com/gsi/style
# << 200 https://seekingalpha.com/samw/static/styles/AuthModal-W.ee0065ca.css
# << 200 https://seekingalpha.com/samw/static/js/c.15589.e2154676.js
# << 200 https://seekingalpha.com/samw/static/js/c.35963.ee87d96c.js
# << 200 https://seekingalpha.com/samw/static/js/c.AuthModal-W.d32afdb8.js
# << 200 https://seekingalpha.com/samw/static/js/c.71470.ee3a2642.js
# << 200 https://connect.facebook.net/en_US/sdk.js
# >> GET https://connect.facebook.net/en_US/sdk.js?hash=6808301fdad254192b332d19f718c40c
# << 200 https://js.stripe.com/v3
# >> POST https://seekingalpha.com/mone_v2
# >> GET https://js.stripe.com/v3/controller-with-preconnect-80d8874f67a84456f0f869a43762e74c.html
# << 200 https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js
# << 200 https://seekingalpha.com/api/v3/product_offers/mpb_1409
# << 200 https://connect.facebook.net/en_US/sdk.js?hash=6808301fdad254192b332d19f718c40c
# << 200 https://js.stripe.com/v3/controller-with-preconnect-80d8874f67a84456f0f869a43762e74c.html
# >> GET https://js.stripe.com/v3/fingerprinted/js/shared-15ac03910c58033e602c4427d7478878.js
# >> GET https://js.stripe.com/v3/fingerprinted/js/controller-with-preconnect-96ea2c54ca0e734b225c1d7c2cad6231.js
# >> POST https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://js.stripe.com/v3/fingerprinted/js/shared-15ac03910c58033e602c4427d7478878.js
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://js.stripe.com/v3/fingerprinted/js/controller-with-preconnect-96ea2c54ca0e734b225c1d7c2cad6231.js
# << 200 https://seekingalpha.com/mone_v2
# >> GET https://js.stripe.com/v3/.deploy_status_henson.json
# >> GET https://js.stripe.com/v3/.deploy_status_henson.json
# >> GET https://js.stripe.com/v3/fingerprinted/data/countries_en-GB-919c91fad2788750937cae126d4af487.json
# >> GET https://js.stripe.com/v3/fingerprinted/data/en-GB-8d206dce22b395634e4501aa9d36ecbd.json
# << 200 https://js.stripe.com/v3/fingerprinted/data/countries_en-GB-919c91fad2788750937cae126d4af487.json
# << 200 https://js.stripe.com/v3/fingerprinted/data/en-GB-8d206dce22b395634e4501aa9d36ecbd.json
# << 200 https://js.stripe.com/v3/.deploy_status_henson.json
# >> GET https://seekingalpha.com/_sa_...
# << 200 https://js.stripe.com/v3/.deploy_status_henson.json
# << 204 https://seekingalpha.com/_sa_...
# >> GET https://seekingalpha.com/_sa_...
# << 204 https://seekingalpha.com/_sa_...
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# >> GET https://ak.sail-horizon.com/spm/spm.v1.min.js
# >> GET https://www.googletagmanager.com/gtm.js?id=GTM-MSK9R8B
# << 200 https://ak.sail-horizon.com/spm/spm.v1.min.js
# >> GET https://api.sail-personalize.com/v1/personalize/simple?pageviews=1&isMobile=0
# << 200 https://www.googletagmanager.com/gtm.js?id=GTM-MSK9R8B
# >> GET https://seekingalpha.com/_sa_...
# >> POST https://www.google.com/ccm/collect?en=page_view&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&scrsrc=www.googletagmanager.com&frm=0&rnd=790004527.1742275781&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&auid=863666191.1742275781&navt=n&npa=0&gtm=45He53d3v812195439za200&gcd=13l3l3l3l1l1&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&tft=1742275780841&tfd=2271&apve=1
# >> GET https://www.googletagmanager.com/gtag/js?id=G-KGRFF2R2C5&l=dataLayer&cx=c&gtm=45He53d3v812195439za200&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719
# >> GET https://bat.bing.com/bat.js
# >> GET https://static.ads-twitter.com/uwt.js
# >> GET https://cdn.taboola.com/libtrc/unip/1788672/tfa.js
# >> GET https://connect.facebook.net/en_US/fbevents.js
# >> GET https://js-eu1.hs-scripts.com/139754362.js
# << 204 https://seekingalpha.com/_sa_...
# >> GET https://www.googletagmanager.com/static/service_worker/53b0/sw_iframe.html?origin=https%3A%2F%2Fseekingalpha.com
# << 200 https://www.google.com/ccm/collect?en=page_view&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&scrsrc=www.googletagmanager.com&frm=0&rnd=790004527.1742275781&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&auid=863666191.1742275781&navt=n&npa=0&gtm=45He53d3v812195439za200&gcd=13l3l3l3l1l1&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&tft=1742275780841&tfd=2271&apve=1
# << 200 https://connect.facebook.net/en_US/fbevents.js
# << 200 https://www.googletagmanager.com/static/service_worker/53b0/sw_iframe.html?origin=https%3A%2F%2Fseekingalpha.com
# >> GET https://connect.facebook.net/signals/config/228550053985270?v=2.9.187&r=stable&domain=seekingalpha.com&hme=9d6c2cc137748d003f279fac8d52b2defc993e1177ef802e0d5b230c72882031&ex_m=71%2C123%2C108%2C112%2C62%2C4%2C101%2C70%2C16%2C98%2C90%2C51%2C55%2C177%2C180%2C192%2C188%2C189%2C191%2C29%2C102%2C53%2C78%2C190%2C172%2C175%2C185%2C186%2C193%2C134%2C41%2C198%2C195%2C196%2C34%2C147%2C15%2C50%2C202%2C201%2C136%2C18%2C40%2C1%2C43%2C66%2C67%2C68%2C72%2C94%2C17%2C14%2C97%2C93%2C92%2C109%2C52%2C111%2C39%2C110%2C30%2C95%2C26%2C173%2C176%2C144%2C87%2C57%2C85%2C33%2C74%2C0%2C96%2C32%2C28%2C83%2C84%2C89%2C47%2C46%2C88%2C37%2C11%2C12%2C13%2C6%2C7%2C25%2C22%2C23%2C58%2C63%2C65%2C76%2C54%2C103%2C27%2C77%2C9%2C8%2C81%2C48%2C21%2C105%2C104%2C106%2C99%2C10%2C20%2C3%2C38%2C75%2C19%2C5%2C91%2C82%2C44%2C35%2C86%2C2%2C36%2C64%2C42%2C107%2C45%2C80%2C69%2C113%2C61%2C60%2C31%2C100%2C59%2C56%2C49%2C79%2C73%2C24%2C114
# << 200 https://www.googletagmanager.com/gtag/js?id=G-KGRFF2R2C5&l=dataLayer&cx=c&gtm=45He53d3v812195439za200&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719
# << 200 https://static.ads-twitter.com/uwt.js
# << 200 https://cdn.taboola.com/libtrc/unip/1788672/tfa.js
# >> POST https://analytics.google.com/g/collect?v=2&tid=G-KGRFF2R2C5&gtm=45je53d3v899945498z8812195439za200zb812195439&_p=1742275779136&_gaz=1&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&cid=1022441734.1742275781&ul=en-gb&sr=1280x720&uaa=x86&uab=64&uafvl=Chromium%3B133.0.6943.16%7CNot(A%253ABrand%3B99.0.0.0&uamb=0&uam=&uap=Linux&uapv=6.8.0&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_s=1&sid=1742275780&sct=1&seg=0&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2399
# >> POST https://stats.g.doubleclick.net/g/collect?v=2&tid=G-KGRFF2R2C5&cid=1022441734.1742275781&gtm=45je53d3v899945498z8812195439za200zb812195439&aip=1&dma=0&gcd=13l3l3l3l1l1&npa=0&frm=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719
# >> GET https://td.doubleclick.net/td/ga/rul?tid=G-KGRFF2R2C5&gacid=1022441734.1742275781&gtm=45je53d3v899945498z8812195439za200zb812195439&dma=0&gcd=13l3l3l3l1l1&npa=0&pscdl=noapi&aip=1&fledge=1&frm=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&z=1140217587
# >> GET https://www.google.com.sg/ads/ga-audiences?v=1&t=sr&slf_rd=1&_r=4&tid=G-KGRFF2R2C5&cid=1022441734.1742275781&gtm=45je53d3v899945498z8812195439za200zb812195439&aip=1&dma=0&gcd=13l3l3l3l1l1&npa=0&frm=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&z=112476383
# >> GET https://t.co/1/i/adsct?bci=4&dv=Asia%2FSingapore%26en-GB%26Google%20Inc.%26Linux%20x86_64%26255%261280%26720%268%2624%261280%26720%260%26na&eci=3&event=%7B%7D&event_id=932b5327-24ab-4506-ba76-63de8e4cc082&integration=gtm&p_id=Twitter&p_user_id=0&pl_id=740c3727-9828-482c-8d18-52cefc54d3da&tw_document_href=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&tw_iframe_status=0&txn_id=o27yc&type=javascript&version=2.3.31
# >> GET https://analytics.twitter.com/1/i/adsct?bci=4&dv=Asia%2FSingapore%26en-GB%26Google%20Inc.%26Linux%20x86_64%26255%261280%26720%268%2624%261280%26720%260%26na&eci=3&event=%7B%7D&event_id=932b5327-24ab-4506-ba76-63de8e4cc082&integration=gtm&p_id=Twitter&p_user_id=0&pl_id=740c3727-9828-482c-8d18-52cefc54d3da&tw_document_href=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&tw_iframe_status=0&txn_id=o27yc&type=javascript&version=2.3.31
# >> GET https://psb.taboola.com/topics_api
# >> GET https://trc.taboola.com/1788672/trc/3/json?tim=1742275781028&data=%7B%22id%22%3A69%2C%22ii%22%3A%22%2Falpha-picks%2Fsubscribe%22%2C%22it%22%3A%22video%22%2C%22sd%22%3Anull%2C%22ui%22%3Anull%2C%22vi%22%3A1742275781013%2C%22cv%22%3A%2220250316-6-RELEASE%22%2C%22uiv%22%3A%22default%22%2C%22u%22%3A%22https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe%22%2C%22e%22%3Anull%2C%22cb%22%3A%22TFASC.trkCallback%22%2C%22qs%22%3A%22%22%2C%22r%22%3A%5B%7B%22li%22%3A%22rbox-tracking%22%2C%22s%22%3A0%2C%22uim%22%3A%22rbox-tracking%3Apub%3Dseekingalphaltd-network%3Aabp%3D0%22%2C%22uip%22%3A%22rbox-tracking%22%2C%22orig_uip%22%3A%22rbox-tracking%22%7D%5D%2C%22mpvd%22%3A%7B%22en%22%3A%22page_view%22%2C%22it%22%3A%22GTM%22%2C%22tim%22%3A1742275781027%2C%22ref%22%3Anull%2C%22item-url%22%3A%22https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe%22%2C%22tos%22%3A6%2C%22ssd%22%3A1%2C%22scd%22%3A0%2C%22supv%22%3Atrue%7D%2C%22pa%22%3A%7B%22su%22%3Atrue%7D%2C%22psb%22%3Atrue%7D&pubit=i
# << 200 https://connect.facebook.net/signals/config/228550053985270?v=2.9.187&r=stable&domain=seekingalpha.com&hme=9d6c2cc137748d003f279fac8d52b2defc993e1177ef802e0d5b230c72882031&ex_m=71%2C123%2C108%2C112%2C62%2C4%2C101%2C70%2C16%2C98%2C90%2C51%2C55%2C177%2C180%2C192%2C188%2C189%2C191%2C29%2C102%2C53%2C78%2C190%2C172%2C175%2C185%2C186%2C193%2C134%2C41%2C198%2C195%2C196%2C34%2C147%2C15%2C50%2C202%2C201%2C136%2C18%2C40%2C1%2C43%2C66%2C67%2C68%2C72%2C94%2C17%2C14%2C97%2C93%2C92%2C109%2C52%2C111%2C39%2C110%2C30%2C95%2C26%2C173%2C176%2C144%2C87%2C57%2C85%2C33%2C74%2C0%2C96%2C32%2C28%2C83%2C84%2C89%2C47%2C46%2C88%2C37%2C11%2C12%2C13%2C6%2C7%2C25%2C22%2C23%2C58%2C63%2C65%2C76%2C54%2C103%2C27%2C77%2C9%2C8%2C81%2C48%2C21%2C105%2C104%2C106%2C99%2C10%2C20%2C3%2C38%2C75%2C19%2C5%2C91%2C82%2C44%2C35%2C86%2C2%2C36%2C64%2C42%2C107%2C45%2C80%2C69%2C113%2C61%2C60%2C31%2C100%2C59%2C56%2C49%2C79%2C73%2C24%2C114
# << 200 https://bat.bing.com/bat.js
# >> GET https://seekingalpha.com/_sa_...
# >> GET https://www.facebook.com/tr/?id=228550053985270&ev=PageView&dl=https%3A%2F%2Fseekingalpha.com&rl=&if=false&ts=1742275781048&sw=1280&sh=720&v=2.9.187&r=stable&ec=0&o=4124&fbp=fb.1.1742275781046.878354961539851126&pm=1&hrl=70fb63&ler=empty&cdl=API_unavailable&it=1742275780927&coo=false&cs_cc=1&cas=1299413000116625%2C8144198265628313%2C8307597809293053%2C7575651669207096%2C8055905074503441%2C24895350630052196%2C6910836088992982%2C6781350998569346%2C6662638950471786%2C4214676558652640%2C2637373326342091%2C2779984665416201%2C3580434481970609%2C2917183195062795%2C2893215474134237%2C2409122662465141&exp=k0&rqm=GET
# >> GET https://www.facebook.com/privacy_sandbox/pixel/register/trigger/?id=228550053985270&ev=PageView&dl=https%3A%2F%2Fseekingalpha.com&rl=&if=false&ts=1742275781048&sw=1280&sh=720&v=2.9.187&r=stable&ec=0&o=4124&fbp=fb.1.1742275781046.878354961539851126&pm=1&hrl=70fb63&ler=empty&cdl=API_unavailable&it=1742275780927&coo=false&cs_cc=1&cas=1299413000116625%2C8144198265628313%2C8307597809293053%2C7575651669207096%2C8055905074503441%2C24895350630052196%2C6910836088992982%2C6781350998569346%2C6662638950471786%2C4214676558652640%2C2637373326342091%2C2779984665416201%2C3580434481970609%2C2917183195062795%2C2893215474134237%2C2409122662465141&exp=k0&rqm=FGET
# >> GET https://bat.bing.com/p/action/25067448.js
# << 200 https://td.doubleclick.net/td/ga/rul?tid=G-KGRFF2R2C5&gacid=1022441734.1742275781&gtm=45je53d3v899945498z8812195439za200zb812195439&dma=0&gcd=13l3l3l3l1l1&npa=0&pscdl=noapi&aip=1&fledge=1&frm=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&z=1140217587
# << 204 https://stats.g.doubleclick.net/g/collect?v=2&tid=G-KGRFF2R2C5&cid=1022441734.1742275781&gtm=45je53d3v899945498z8812195439za200zb812195439&aip=1&dma=0&gcd=13l3l3l3l1l1&npa=0&frm=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719
# << 204 https://seekingalpha.com/_sa_...
# << 204 https://analytics.google.com/g/collect?v=2&tid=G-KGRFF2R2C5&gtm=45je53d3v899945498z8812195439za200zb812195439&_p=1742275779136&_gaz=1&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&cid=1022441734.1742275781&ul=en-gb&sr=1280x720&uaa=x86&uab=64&uafvl=Chromium%3B133.0.6943.16%7CNot(A%253ABrand%3B99.0.0.0&uamb=0&uam=&uap=Linux&uapv=6.8.0&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_s=1&sid=1742275780&sct=1&seg=0&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&en=page_view&_fv=1&_nsi=1&_ss=1&tfd=2399
# << 200 https://trc.taboola.com/1788672/trc/3/json?tim=1742275781028&data=%7B%22id%22%3A69%2C%22ii%22%3A%22%2Falpha-picks%2Fsubscribe%22%2C%22it%22%3A%22video%22%2C%22sd%22%3Anull%2C%22ui%22%3Anull%2C%22vi%22%3A1742275781013%2C%22cv%22%3A%2220250316-6-RELEASE%22%2C%22uiv%22%3A%22default%22%2C%22u%22%3A%22https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe%22%2C%22e%22%3Anull%2C%22cb%22%3A%22TFASC.trkCallback%22%2C%22qs%22%3A%22%22%2C%22r%22%3A%5B%7B%22li%22%3A%22rbox-tracking%22%2C%22s%22%3A0%2C%22uim%22%3A%22rbox-tracking%3Apub%3Dseekingalphaltd-network%3Aabp%3D0%22%2C%22uip%22%3A%22rbox-tracking%22%2C%22orig_uip%22%3A%22rbox-tracking%22%7D%5D%2C%22mpvd%22%3A%7B%22en%22%3A%22page_view%22%2C%22it%22%3A%22GTM%22%2C%22tim%22%3A1742275781027%2C%22ref%22%3Anull%2C%22item-url%22%3A%22https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe%22%2C%22tos%22%3A6%2C%22ssd%22%3A1%2C%22scd%22%3A0%2C%22supv%22%3Atrue%7D%2C%22pa%22%3A%7B%22su%22%3Atrue%7D%2C%22psb%22%3Atrue%7D&pubit=i
# << 200 https://www.google.com.sg/ads/ga-audiences?v=1&t=sr&slf_rd=1&_r=4&tid=G-KGRFF2R2C5&cid=1022441734.1742275781&gtm=45je53d3v899945498z8812195439za200zb812195439&aip=1&dma=0&gcd=13l3l3l3l1l1&npa=0&frm=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&z=112476383
# >> GET https://cdn.taboola.com/scripts/cds-pips.js
# >> GET https://cdn.taboola.com/scripts/eid.es5.js
# << 200 https://cdn.taboola.com/scripts/cds-pips.js
# >> GET https://pips.taboola.com/
# << 200 https://psb.taboola.com/topics_api
# << 200 https://www.facebook.com/tr/?id=228550053985270&ev=PageView&dl=https%3A%2F%2Fseekingalpha.com&rl=&if=false&ts=1742275781048&sw=1280&sh=720&v=2.9.187&r=stable&ec=0&o=4124&fbp=fb.1.1742275781046.878354961539851126&pm=1&hrl=70fb63&ler=empty&cdl=API_unavailable&it=1742275780927&coo=false&cs_cc=1&cas=1299413000116625%2C8144198265628313%2C8307597809293053%2C7575651669207096%2C8055905074503441%2C24895350630052196%2C6910836088992982%2C6781350998569346%2C6662638950471786%2C4214676558652640%2C2637373326342091%2C2779984665416201%2C3580434481970609%2C2917183195062795%2C2893215474134237%2C2409122662465141&exp=k0&rqm=GET
# << 200 https://cdn.taboola.com/scripts/eid.es5.js
# >> GET https://trc.taboola.com/sg/tfa-eid/1/um/?uils=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&eflp=7%3D%3A%3B%3A%3C%3Ai%3Aj85g6ji%3DWZq7VZ%3A9%5BSJW%5BXKk%3A5875%3E7h87h%3B%3B6i%3C%3E%3Cjg59%3A%3Ckfjjh8i5h%3Cgih877%3A%3D7%3D7g
# << 200 https://pips.taboola.com/
# >> GET https://cds.taboola.com/?uid=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ptf=TGludXg=&ptfv=Ni44LjA=&ufv=MTMzLjAuNjk0My4xNg==&bnd=Q2hyb21pdW0=&bndv=MTMz&bnd=Tm90KEE6QnJhbmQ=&bndv=OTk=&mbl=ZmFsc2U=
# << 200 https://trc.taboola.com/sg/tfa-eid/1/um/?uils=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&eflp=7%3D%3A%3B%3A%3C%3Ai%3Aj85g6ji%3DWZq7VZ%3A9%5BSJW%5BXKk%3A5875%3E7h87h%3B%3B6i%3C%3E%3Cjg59%3A%3Ckfjjh8i5h%3Cgih877%3A%3D7%3D7g
# >> POST https://r.stripe.com/b
# >> POST https://r.stripe.com/b
# << 200 https://bat.bing.com/p/action/25067448.js
# >> GET https://bat.bing.com/p/insights/t/25067448
# >> GET https://bat.bing.com/action/0?ti=25067448&tm=gtm002&Ver=2&mid=ea5fc1aa-4027-456a-a38f-0a0a7dc096de&bo=1&sid=fddd073003b911f08719434643c432ad&vid=fddd0bd003b911f0b04a178322bc6418&vids=1&msclkid=N&pi=918639831&lg=en-GB&sw=1280&sh=720&sc=24&nwd=1&tl=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&p=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&r=&lt=641&evt=pageLoad&sv=1&cdb=AQAQ&rn=54100
# << 204 https://bat.bing.com/action/0?ti=25067448&tm=gtm002&Ver=2&mid=ea5fc1aa-4027-456a-a38f-0a0a7dc096de&bo=1&sid=fddd073003b911f08719434643c432ad&vid=fddd0bd003b911f0b04a178322bc6418&vids=1&msclkid=N&pi=918639831&lg=en-GB&sw=1280&sh=720&sc=24&nwd=1&tl=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&p=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&r=&lt=641&evt=pageLoad&sv=1&cdb=AQAQ&rn=54100
# << 200 https://analytics.twitter.com/1/i/adsct?bci=4&dv=Asia%2FSingapore%26en-GB%26Google%20Inc.%26Linux%20x86_64%26255%261280%26720%268%2624%261280%26720%260%26na&eci=3&event=%7B%7D&event_id=932b5327-24ab-4506-ba76-63de8e4cc082&integration=gtm&p_id=Twitter&p_user_id=0&pl_id=740c3727-9828-482c-8d18-52cefc54d3da&tw_document_href=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&tw_iframe_status=0&txn_id=o27yc&type=javascript&version=2.3.31
# << 200 https://t.co/1/i/adsct?bci=4&dv=Asia%2FSingapore%26en-GB%26Google%20Inc.%26Linux%20x86_64%26255%261280%26720%268%2624%261280%26720%260%26na&eci=3&event=%7B%7D&event_id=932b5327-24ab-4506-ba76-63de8e4cc082&integration=gtm&p_id=Twitter&p_user_id=0&pl_id=740c3727-9828-482c-8d18-52cefc54d3da&tw_document_href=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&tw_iframe_status=0&txn_id=o27yc&type=javascript&version=2.3.31
# << 200 https://www.facebook.com/privacy_sandbox/pixel/register/trigger/?id=228550053985270&ev=PageView&dl=https%3A%2F%2Fseekingalpha.com&rl=&if=false&ts=1742275781048&sw=1280&sh=720&v=2.9.187&r=stable&ec=0&o=4124&fbp=fb.1.1742275781046.878354961539851126&pm=1&hrl=70fb63&ler=empty&cdl=API_unavailable&it=1742275780927&coo=false&cs_cc=1&cas=1299413000116625%2C8144198265628313%2C8307597809293053%2C7575651669207096%2C8055905074503441%2C24895350630052196%2C6910836088992982%2C6781350998569346%2C6662638950471786%2C4214676558652640%2C2637373326342091%2C2779984665416201%2C3580434481970609%2C2917183195062795%2C2893215474134237%2C2409122662465141&exp=k0&rqm=FGET
# << 200 https://bat.bing.com/p/insights/t/25067448
# >> GET https://bat.bing.com/p/insights/s/0.8.0
# << 200 https://js-eu1.hs-scripts.com/139754362.js
# >> GET https://js-eu1.hs-analytics.net/analytics/1742272800000/139754362.js
# >> GET https://js-eu1.usemessages.com/conversations-embed.js
# >> GET https://js-eu1.hs-banner.com/v2/139754362/banner.js
# >> GET https://js-eu1.hubspot.com/web-interactives-embed.js
# << 200 https://bat.bing.com/p/insights/s/0.8.0
# >> GET https://seekingalpha.com/samw/static/js/c.9738.c3919826.js
# >> GET https://seekingalpha.com/samw/static/js/c.rollBarEntry-W.c2ab065e.js
# >> GET https://seekingalpha.com/xgCxM9By/init.js
# >> POST https://bat.bing.com/p/insights/c/e
# << 200 https://seekingalpha.com/samw/static/js/c.rollBarEntry-W.c2ab065e.js
# << 200 https://seekingalpha.com/samw/static/js/c.9738.c3919826.js
# << 204 https://cds.taboola.com/?uid=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ptf=TGludXg=&ptfv=Ni44LjA=&ufv=MTMzLjAuNjk0My4xNg==&bnd=Q2hyb21pdW0=&bndv=MTMz&bnd=Tm90KEE6QnJhbmQ=&bndv=OTk=&mbl=ZmFsc2U=
# << 200 https://api.sail-personalize.com/v1/personalize/simple?pageviews=1&isMobile=0
# << 200 https://r.stripe.com/b
# << 200 https://r.stripe.com/b
# << 200 https://bat.bing.com/p/insights/c/e
# >> POST https://seekingalpha.com/mone_v2
# >> POST https://seekingalpha.com/api/v3/login_tokens
# >> POST https://analytics.google.com/g/collect?v=2&tid=G-KGRFF2R2C5&gtm=45je53d3v899945498z8812195439za200zb812195439&_p=1742275779136&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&cid=1022441734.1742275781&ul=en-gb&sr=1280x720&uaa=x86&uab=64&uafvl=Chromium%3B133.0.6943.16%7CNot(A%253ABrand%3B99.0.0.0&uamb=0&uam=&uap=Linux&uapv=6.8.0&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_s=2&sid=1742275780&sct=1&seg=0&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&en=signin_popup_shown&ep.category=Sign%20in&ep.action=Sign%20in%20presented&ep.label=Sign%20in%20presented&_et=27&tfd=3497
# Login did not redirect as expected. Current URL: https://seekingalpha.com/alpha-picks/subscribe
# << 204 https://analytics.google.com/g/collect?v=2&tid=G-KGRFF2R2C5&gtm=45je53d3v899945498z8812195439za200zb812195439&_p=1742275779136&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&cid=1022441734.1742275781&ul=en-gb&sr=1280x720&uaa=x86&uab=64&uafvl=Chromium%3B133.0.6943.16%7CNot(A%253ABrand%3B99.0.0.0&uamb=0&uam=&uap=Linux&uapv=6.8.0&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_s=2&sid=1742275780&sct=1&seg=0&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&en=signin_popup_shown&ep.category=Sign%20in&ep.action=Sign%20in%20presented&ep.label=Sign%20in%20presented&_et=27&tfd=3497
# << 200 https://js-eu1.hs-banner.com/v2/139754362/banner.js
# << 200 https://js-eu1.usemessages.com/conversations-embed.js
# >> GET https://api-eu1.hubspot.com/livechat-public/v1/message/public?portalId=139754362&conversations-embed=static-1.20914&mobile=false&messagesUtk=62bb2a93514b4990813bada1e2a65831&traceId=62bb2a93514b4990813bada1e2a65831
# << 200 https://js-eu1.hs-analytics.net/analytics/1742272800000/139754362.js
# << 200 https://js-eu1.hubspot.com/web-interactives-embed.js
# >> GET https://track-eu1.hubspot.com/__ptq.gif?k=1&sd=1280x720&cd=24-bit&cs=UTF-8&ln=en-gb&bfp=215645102&v=1.1&a=139754362&rcu=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&pu=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&t=Alpha+Picks%3A+2+Stock+Picks+Per+Month+by+Quant+Rating+%7C+Seeking+Alpha+Subscription&cts=1742275782289&vi=4b944041fc671f65c128d4bcd554615b&nc=true&u=234155329.4b944041fc671f65c128d4bcd554615b.1742275782284.1742275782284.1742275782284.1&b=234155329.1.1742275782284&cc=15
# >> GET https://cta-eu1.hubspot.com/web-interactives/public/v1/embed/combinedConfigs?portalId=139754362&currentUrl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&utk=4b944041fc671f65c128d4bcd554615b&__hstc=234155329.4b944041fc671f65c128d4bcd554615b.1742275782284.1742275782284.1742275782284.1&__hssc=234155329.1.1742275782284
# << 200 https://seekingalpha.com/xgCxM9By/init.js
# >> GET https://stk.px-cloud.net/ns?c=fe8ecd50-03b9-11f0-b51b-ef1a5e055a16
# >> GET https://crcldu.com/bd/h.php
# >> POST https://collector-pxxgcxm9by.cl6.px-cloud.net/api/v2/collector
# << 403 https://seekingalpha.com/api/v3/login_tokens
# >> POST https://seekingalpha.com/mone_v2
# << 200 https://seekingalpha.com/mone_v2
# << 200 https://crcldu.com/bd/h.php
# << 200 https://stk.px-cloud.net/ns?c=fe8ecd50-03b9-11f0-b51b-ef1a5e055a16
# << 200 https://collector-pxxgcxm9by.cl6.px-cloud.net/api/v2/collector
# << 200 https://seekingalpha.com/mone_v2
# >> POST https://bat.bing.com/p/insights/c/e
# << 200 https://track-eu1.hubspot.com/__ptq.gif?k=1&sd=1280x720&cd=24-bit&cs=UTF-8&ln=en-gb&bfp=215645102&v=1.1&a=139754362&rcu=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&pu=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&t=Alpha+Picks%3A+2+Stock+Picks+Per+Month+by+Quant+Rating+%7C+Seeking+Alpha+Subscription&cts=1742275782289&vi=4b944041fc671f65c128d4bcd554615b&nc=true&u=234155329.4b944041fc671f65c128d4bcd554615b.1742275782284.1742275782284.1742275782284.1&b=234155329.1.1742275782284&cc=15
# << 200 https://cta-eu1.hubspot.com/web-interactives/public/v1/embed/combinedConfigs?portalId=139754362&currentUrl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&utk=4b944041fc671f65c128d4bcd554615b&__hstc=234155329.4b944041fc671f65c128d4bcd554615b.1742275782284.1742275782284.1742275782284.1&__hssc=234155329.1.1742275782284
# >> GET https://perf-eu1.hsforms.com/embed/v3/counters.gif?key=config-loaded-success&value=1
# >> POST https://collector-pxxgcxm9by.cl6.px-cloud.net/api/v2/collector
# << 204 https://bat.bing.com/p/insights/c/e
# << 200 https://api-eu1.hubspot.com/livechat-public/v1/message/public?portalId=139754362&conversations-embed=static-1.20914&mobile=false&messagesUtk=62bb2a93514b4990813bada1e2a65831&traceId=62bb2a93514b4990813bada1e2a65831
# << 200 https://collector-pxxgcxm9by.cl6.px-cloud.net/api/v2/collector
# << 200 https://perf-eu1.hsforms.com/embed/v3/counters.gif?key=config-loaded-success&value=1
# >> GET https://js.stripe.com/v3/m-outer-3437aaddcdf6922d623e172c2d6f9278.html
# << 200 https://js.stripe.com/v3/m-outer-3437aaddcdf6922d623e172c2d6f9278.html
# >> GET https://js.stripe.com/v3/fingerprinted/js/m-outer-15a2b40a058ddff1cffdb63779fe3de1.js
# << 200 https://js.stripe.com/v3/fingerprinted/js/m-outer-15a2b40a058ddff1cffdb63779fe3de1.js
# >> GET https://m.stripe.network/inner.html
# << 200 https://m.stripe.network/inner.html
# >> GET https://m.stripe.network/out-4.5.44.js
# << 200 https://m.stripe.network/out-4.5.44.js
# >> POST https://collector-pxxgcxm9by.cl6.px-cloud.net/api/v2/collector
# >> POST https://m.stripe.com/6
# >> GET https://js.stripe.com/v3/fingerprinted/js/trusted-types-checker-efd8cf45ce422659c098993bfc62531b.js
# << 200 https://js.stripe.com/v3/fingerprinted/js/trusted-types-checker-efd8cf45ce422659c098993bfc62531b.js
# << 200 https://collector-pxxgcxm9by.cl6.px-cloud.net/api/v2/collector
# >> GET https://trc-events.taboola.com/1788672/log/3/unip?en=pre_d_eng_tb&tos=4559&scd=0&ssd=1&est=1742275781020&ver=36&isls=true&src=i&invt=4500&msa=4174&rv=1&tim=1742275785578&vi=1742275781013&ri=02632ca8252e09fa85f1912488e41ac1&sd=v2_840a1585b324a87c040fd268bdc0dd00_5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45_1742275781_1742275781_CNawjgYQgJZtGJXD6r3aMiABKAEwwAE4t4gNQOWaEEinqtoDUP___________wFYAGAAaIOcg6Wf9-qJpAFwAYABAA&ui=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ref=null&cv=20250316-6-RELEASE&item-url=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&it=JS_PIXEL
# << 204 https://trc-events.taboola.com/1788672/log/3/unip?en=pre_d_eng_tb&tos=4559&scd=0&ssd=1&est=1742275781020&ver=36&isls=true&src=i&invt=4500&msa=4174&rv=1&tim=1742275785578&vi=1742275781013&ri=02632ca8252e09fa85f1912488e41ac1&sd=v2_840a1585b324a87c040fd268bdc0dd00_5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45_1742275781_1742275781_CNawjgYQgJZtGJXD6r3aMiABKAEwwAE4t4gNQOWaEEinqtoDUP___________wFYAGAAaIOcg6Wf9-qJpAFwAYABAA&ui=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ref=null&cv=20250316-6-RELEASE&item-url=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&it=JS_PIXEL
# << 200 https://m.stripe.com/6
# >> POST https://r.stripe.com/b
# >> POST https://analytics.google.com/g/collect?v=2&tid=G-KGRFF2R2C5&gtm=45je53d3v899945498za200zb812195439&_p=1742275779136&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&cid=1022441734.1742275781&ul=en-gb&sr=1280x720&uaa=x86&uab=64&uafvl=Chromium%3B133.0.6943.16%7CNot(A%253ABrand%3B99.0.0.0&uamb=0&uam=&uap=Linux&uapv=6.8.0&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_eu=AEE&_s=3&sid=1742275780&sct=1&seg=0&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&en=form_start&ep.form_id=&ep.form_name=&ep.form_destination=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&epn.form_length=4&ep.first_field_id=signInPasswordField&ep.first_field_name=password&ep.first_field_type=password&epn.first_field_position=2&_et=1053&tfd=8498
# << 200 https://r.stripe.com/b
# << 204 https://analytics.google.com/g/collect?v=2&tid=G-KGRFF2R2C5&gtm=45je53d3v899945498za200zb812195439&_p=1742275779136&gcd=13l3l3l3l1l1&npa=0&dma=0&tag_exp=102482433~102587591~102717422~102788824~102813109~102814060~102825837~102879719&cid=1022441734.1742275781&ul=en-gb&sr=1280x720&uaa=x86&uab=64&uafvl=Chromium%3B133.0.6943.16%7CNot(A%253ABrand%3B99.0.0.0&uamb=0&uam=&uap=Linux&uapv=6.8.0&uaw=0&are=1&pae=1&frm=0&pscdl=noapi&_eu=AEE&_s=3&sid=1742275780&sct=1&seg=0&dl=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&dt=Alpha%20Picks%3A%202%20Stock%20Picks%20Per%20Month%20by%20Quant%20Rating%20%7C%20Seeking%20Alpha%20Subscription&en=form_start&ep.form_id=&ep.form_name=&ep.form_destination=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&epn.form_length=4&ep.first_field_id=signInPasswordField&ep.first_field_name=password&ep.first_field_type=password&epn.first_field_position=2&_et=1053&tfd=8498
# >> GET https://trc-events.taboola.com/1788672/log/3/unip?en=pre_d_eng_tb&tos=10062&scd=0&ssd=1&est=1742275781020&ver=36&isls=true&src=i&invt=5500&msa=4174&rv=1&tim=1742275791083&vi=1742275781013&ri=02632ca8252e09fa85f1912488e41ac1&sd=v2_840a1585b324a87c040fd268bdc0dd00_5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45_1742275781_1742275781_CNawjgYQgJZtGJXD6r3aMiABKAEwwAE4t4gNQOWaEEinqtoDUP___________wFYAGAAaIOcg6Wf9-qJpAFwAYABAA&ui=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ref=null&cv=20250316-6-RELEASE&item-url=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&it=JS_PIXEL
# << 204 https://trc-events.taboola.com/1788672/log/3/unip?en=pre_d_eng_tb&tos=10062&scd=0&ssd=1&est=1742275781020&ver=36&isls=true&src=i&invt=5500&msa=4174&rv=1&tim=1742275791083&vi=1742275781013&ri=02632ca8252e09fa85f1912488e41ac1&sd=v2_840a1585b324a87c040fd268bdc0dd00_5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45_1742275781_1742275781_CNawjgYQgJZtGJXD6r3aMiABKAEwwAE4t4gNQOWaEEinqtoDUP___________wFYAGAAaIOcg6Wf9-qJpAFwAYABAA&ui=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ref=null&cv=20250316-6-RELEASE&item-url=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&it=JS_PIXEL
# >> GET https://trc-events.taboola.com/1788672/log/3/unip?en=pre_d_eng_tb&tos=20065&scd=0&ssd=1&est=1742275781020&ver=36&isls=true&src=i&invt=10000&msa=4174&rv=1&tim=1742275801086&vi=1742275781013&ri=02632ca8252e09fa85f1912488e41ac1&sd=v2_840a1585b324a87c040fd268bdc0dd00_5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45_1742275781_1742275781_CNawjgYQgJZtGJXD6r3aMiABKAEwwAE4t4gNQOWaEEinqtoDUP___________wFYAGAAaIOcg6Wf9-qJpAFwAYABAA&ui=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ref=null&cv=20250316-6-RELEASE&item-url=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&it=JS_PIXEL
# << 204 https://trc-events.taboola.com/1788672/log/3/unip?en=pre_d_eng_tb&tos=20065&scd=0&ssd=1&est=1742275781020&ver=36&isls=true&src=i&invt=10000&msa=4174&rv=1&tim=1742275801086&vi=1742275781013&ri=02632ca8252e09fa85f1912488e41ac1&sd=v2_840a1585b324a87c040fd268bdc0dd00_5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45_1742275781_1742275781_CNawjgYQgJZtGJXD6r3aMiABKAEwwAE4t4gNQOWaEEinqtoDUP___________wFYAGAAaIOcg6Wf9-qJpAFwAYABAA&ui=5f60d98e-f6d3-4c36-b882-6174a7e6d7e2-tucted28a45&ref=null&cv=20250316-6-RELEASE&item-url=https%3A%2F%2Fseekingalpha.com%2Falpha-picks%2Fsubscribe&it=JS_PIXEL
# (web) ckabundant@HP-Laptop:~/Documents/sentiment$

# %%
import os
import random
import time
from dotenv import load_dotenv
from playwright.sync_api import sync_playwright


def human_delay(min_ms=800, max_ms=2500):
    """Simulate human-like delays."""
    time.sleep(random.uniform(min_ms / 1000, max_ms / 1000))


def advanced_stealth(page):
    """Apply advanced stealth techniques to bypass bot detection."""
    # Override browser properties to mimic a real user
    page.add_init_script(
        """
        Object.defineProperty(navigator, 'webdriver', {
            get: () => undefined,
            configurable: true
        });
        Object.defineProperty(navigator, 'plugins', {
            get: () => [1, 2, 3] // Fake plugins list
        });
        Object.defineProperty(navigator, 'languages', {
            get: () => ['en-US', 'en']
        });
        window.navigator.chrome = {
            app: { isInstalled: false },
            webstore: { onInstallStageChanged: {}, onDownloadProgress: {} },
            runtime: { platformArch: 'Linux x86_64', platformNaclArch: 'Linux x86_64' }
        };
    """
    )

    # Randomize viewport
    viewport_width = 1280 + random.randint(-50, 50)
    viewport_height = 720 + random.randint(-30, 30)
    page.set_viewport_size({"width": viewport_width, "height": viewport_height})

    # Spoof screen properties
    page.evaluate(
        """() => {  
        Object.defineProperty(screen, 'availWidth', { value: %d });  
        Object.defineProperty(screen, 'availHeight', { value: %d });  
    }"""
        % (viewport_width, viewport_height)
    )


def behavioral_login(page, selector, text, delay_range=(50, 150)):
    """Simulate human-like typing behavior."""
    element = page.wait_for_selector(selector)
    human_delay(300, 800)  # Pause before interacting
    element.hover()
    for char in text:
        element.type(char, delay=random.randint(*delay_range))
        human_delay(50, 150)


def main():
    load_dotenv()  # Load environment variables from .env file

    with sync_playwright() as p:
        # Launch browser with stealth settings
        browser = p.chromium.launch(
            headless=False,
            args=["--disable-blink-features=AutomationControlled", "--start-maximized"],
        )

        context = browser.new_context(
            user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36",
            locale="en-US",
            color_scheme=random.choice(["light", "dark"]),  # Randomize light/dark mode
            viewport={"width": 1280, "height": 720},
        )

        page = context.new_page()

        # Apply advanced stealth techniques
        advanced_stealth(page)

        # Block known tracking and CAPTCHA scripts
        page.route("**/*captcha*", lambda route: route.abort())
        page.route("**/*google-analytics*", lambda route: route.abort())

        # Navigate to the login page
        login_url = "https://seekingalpha.com/alpha-picks/subscribe"
        cur_url = "https://seekingalpha.com/alpha-picks/picks/current"
        page.goto(login_url)
        page.wait_for_url(login_url)

        # Click the 'LOG IN' button
        page.locator("button:has-text('LOG IN')").click()

        # Wait for the login form to appear
        xpath = "//div[@data-test-id='modal-content']//button[@data-test-id='sign-in-button']"
        page.wait_for_selector(xpath)

        # Fill in email and password using human-like behavior
        behavioral_login(page, "[name='email']", os.getenv("ALPHA_EMAIL"))
        behavioral_login(page, "[name='password']", os.getenv("ALPHA_PASSWORD"))

        # Simulate human-like mouse movement and click the 'Sign In' button
        submit_button = page.locator(xpath)
        box = submit_button.bounding_box()

        for _ in range(3):  # Simulate natural mouse movements before clicking
            page.mouse.move(
                box["x"] + random.randint(10, box["width"] - 10),
                box["y"] + random.randint(10, box["height"] - 10),
                steps=random.randint(5, 15),
            )
            human_delay(50, 200)

        submit_button.click()

        # Wait for redirection or CAPTCHA trigger
        try:
            page.wait_for_url(cur_url, timeout=15000)
            print("Login successful and redirected!")
            content = page.content()
            print(
                content[:500]
            )  # Print first 500 characters of the HTML for verification
        except Exception as e:
            print(f"Login failed or CAPTCHA triggered: {e}")
            page.screenshot(path="debug.png")  # Save screenshot for debugging

        browser.close()


if __name__ == "__main__":
    main()

# %% [markdown]
# | S/N | Request Header      | Ranking          | Description                                                                                                                                                                             |
# | --- | ------------------- | ---------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | 1.  | :authority:         | Critical         | &bull; Specifies the domain of the server being accessed (e.g., example.com). <br>&bull; This is critical for HTTP/2 requests.                                                          |
# | 2.  | :method:            | Critical         | &bull; Indicates the HTTP method used (e.g., GET, POST). <br>&bull; Ensure it matches the operation you're performing.                                                                  |
# | 3.  | :path:              | Critical         | &bull; The specific endpoint being requested (e.g., /alpha-picks/subscribe). <br>&bull; It must accurately reflect the URL path.                                                        |
# | 4.  | :scheme:            | Critical         | &bull; Specifies the protocol (https or http). <br>&bull; Critical for HTTP/2 requests.                                                                                                 |
# | 5.  | accept:             | Critical         | &bull; Defines acceptable response formats (e.g., text/html, application/json). <br>&bull; Must match what a browser typically sends.                                                   |
# | 6.  | accept-encoding:    | Optional         | &bull; Specifies supported compression formats (e.g., gzip, br). <br>&bull; Typically included but not always critical.                                                                 |
# | 7.  | accept-language:    | Critical         | &bull; Indicates preferred language(s) for content (e.g., en-US,en;q=0.9). <br>&bull; Important for localization.                                                                       |
# | 8.  | content-length:     | Optional         | &bull; Length of the request body in bytes. <br>&bull; Required for POST requests but irrelevant for GET requests.                                                                      |
# | 9.  | content-type:       | Optional         | &bull; Specifies the type of data being sent in a request body (e.g., application/json, application/x-www-form-urlencoded). <br>&bull; Relevant for POST requests but not GET requests. |
# | 10. | cookie:             | Optional         | &bull; Required if authentication or session management depends on cookies. <br>&bull; If cookies are not necessary, this can be omitted.                                               |
# | 11. | origin:             | Optional         | &bull; Indicates the origin of the request, often used in cross-origin requests (e.g., during form submissions). <br>&bull; Include only if relevant.                                   |
# | 12. | priority:           | Context Specific | &bull; Used in HTTP/2 to specify request priority. <br>&bull; Typically handled automatically by browsers and may not need manual inclusion.                                            |
# | 13. | referer:            | Critical         | &bull; Specifies the URL of the previous page that led to this request. <br>&bull; Often checked to ensure legitimate navigation paths.                                                 |
# | 14. | sec-ch-ua:          | Critical         | &bull; Provides client hints about the browser and version (e.g., "Chromium";v="125", "Not.A/Brand";v="24"). <br>&bull; Important for mimicking browser behavior.                       |
# | 15. | sec-ch-ua-mobile:   | Critical         | &bull; Indicates whether the client is on a mobile device (?0 for desktop, ?1 for mobile).                                                                                              |
# | 16. | sec-ch-ua-platform: | Critical         | &bull; Specifies the operating system (e.g., Windows, macOS). <br>&bull; Helps with fingerprinting checks.                                                                              |
# | 17. | sec-fetch-dest:     | Context Specific | &bull; Indicates the destination of the fetch request (e.g., document, script, image). <br>&bull; Useful for mimicking browser behavior but context-specific.                           |
# | 18. | sec-fetch-mode:     | Context Specific | &bull; Specifies how resources are fetched (e.g., navigate, cors, same-origin). <br>&bull; Include if observed in real browser traffic for your target website.                         |
# | 19. | sec-fetch-site:     | Context Specific | &bull; Describes the relationship between the origin of the page and requested resource (e.g., same-origin, cross-site). <br>&bull; Important for anti-bot checks.                      |
# | 20. | user-agent:         | Critical         | &bull; Identifies the browser, OS, and device type (e.g., Mozilla/5.0 ...). <br>&bull; One of the most critical headers.                                                                |

# %% [markdown]
# | S/N | Request Header      | Value                                                                                                 |
# | --- | ------------------- | ----------------------------------------------------------------------------------------------------- |
# | 1.  | :authority:         | seekingalpha.com                                                                                      |
# | 2.  | :method:            | POST                                                                                                  |
# | 3.  | :path:              | /api/v3/login_tokens                                                                                  |
# | 4.  | :scheme:            | https                                                                                                 |
# | 5.  | accept:             | application/json                                                                                      |
# | 6.  | accept-encoding:    | gzip, deflate, br, zstd                                                                               |
# | 7.  | accept-language:    | en-US,en;q=0.9                                                                                        |
# | 8.  | content-length:     | 120                                                                                                   |
# | 9.  | content-type:       | application/json                                                                                      |
# | 10. | cookie:             | machine_cookie=...                                                                                    |
# | 11. | origin:             | https://seekingalpha.com                                                                              |
# | 12. | priority:           | u=1, i                                                                                                |
# | 13. | referer:            | https://seekingalpha.com/alpha-picks/subscribe                                                        |
# | 14. | sec-ch-ua:          | "Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"                                     |
# | 15. | sec-ch-ua-mobile:   | ?0                                                                                                    |
# | 16. | sec-ch-ua-platform: | "Linux"                                                                                               |
# | 17. | sec-fetch-dest:     | empty                                                                                                 |
# | 18. | sec-fetch-mode:     | cors                                                                                                  |
# | 19. | sec-fetch-site:     | same-origin                                                                                           |
# | 20. | user-agent:         | Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 |

# %%
text
# Out:
# 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36'

# %%
import platform
from pprint import pformat


def get_runtime(user_agent: str) -> str:
    """Get operating system from user-agent for desktop device only i.e. 'Chrome OS',
    'Chromium OS', 'Linux', 'macOS', and 'Windows'."""

    # Get processor architecture
    proc_arch = platform.machine()

    mapping = {
        "Linux": {
            "PlatformOs": "linux",
            # "PlatformArch": proc_arch,
            # "PlatformNaclArch": proc_arch,
        },
        "Macintosh": {
            "PlatformOs": "mac",
            # "PlatformArch": proc_arch,
            # "PlatformNaclArch": proc_arch,
        },
        "Windows": {
            "PlatformOs": "win",
            # "PlatformArch": proc_arch,
            # "PlatformNaclArch": proc_arch,
        },
        "CrOS x86_64": {
            "PlatformOs": "cros",
            # "PlatformArch": proc_arch,
            # "PlatformNaclArch": proc_arch,
        },
    }

    arch_dict = {
        "PlatformArch": proc_arch,
        "PlatformNaclArch": proc_arch,
    }

    mapping = {k: dict(**v, **arch_dict) for k, v in mapping.items()}

    return mapping


get_runtime(pformat(text, sort_dicts=False))
# Out:
# {'Linux': {'PlatformOs': 'linux',
#   'PlatformArch': 'x86_64',
#   'PlatformNaclArch': 'x86_64'},
#  'Macintosh': {'PlatformOs': 'mac',
#   'PlatformArch': 'x86_64',
#   'PlatformNaclArch': 'x86_64'},
#  'Windows': {'PlatformOs': 'win',
#   'PlatformArch': 'x86_64',
#   'PlatformNaclArch': 'x86_64'},
#  'CrOS x86_64': {'PlatformOs': 'cros',
#   'PlatformArch': 'x86_64',
#   'PlatformNaclArch': 'x86_64'}}

# %%
import re

pattern = r"\d+(?=\b)"  # Match digits followed by a word boundary
text = "123abc1.456 def789"

matches = re.findall(pattern, text)
print(matches)  # Output: ['123', '456', '789']
# Out:
# ['1', '456', '789']

# %%
import platform

platform.machine()
# Out:
# 'x86_64'

# %%
text = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36"

re.findall(r"(?<=Chrome/)\d+", text)
# Out:
# ['134']

# %%
import re

pattern = r"(?<=\$)\d+"  # Match digits preceded by a dollar sign
text = "The price is $50 for one item and $30 for another."

matches = re.findall(pattern, text)
print(matches)  # Output: ['50', '30']
# Out:
# ['50', '30']

# %% [markdown]
# ec-ch-ua:
# "Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"
# sec-ch-ua-mobile:
# ?0
# sec-ch-ua-platform:
# "Linux"
# sec-fetch-dest:
# empty
# sec-fetch-mode:
# cors
# sec-fetch-site:
# same-origin
# user-agent:
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36

# %% [markdown]
# async def randomize_webgl(page):
# await page.add_init_script("""
# () => {
# const gpus = [
# 'ANGLE (NVIDIA, NVIDIA GeForce RTX 3080 Direct3D11 vs_5_0 ps_5_0)',
# 'Intel Iris Xe Graphics',
# 'AMD Radeon Pro 5500M OpenGL Engine'
# ];
# const getParameter = WebGLRenderingContext.prototype.getParameter;
# WebGLRenderingContext.prototype.getParameter = function(parameter) {
# if (parameter === 37445) return gpus[Math.floor(Math.random()*3)];
# return getParameter.call(this, parameter);
# };
# }
# """)

# %%
plugins = [
    {
        "name": "Chromium PDF Viewer",
        "description": "Portable Document Format",
        "filename": "mhjfbmdgcfjbbpaeojofohoefgiehjai",
    },
    {
        "name": "Native Client",
        "description": "Native Client Execution",
        "filename": "internal-nacl-plugin",
    },
    {
        "name": "PDF Viewer",
        "description": "Portable Document Format",
        "filename": "oemmndcbldboiebfnladdacbdfmadadm",
    },
]

a = append_mimetypes(plugins)
print(pformat(a, sort_dicts=False))
# Out:
# [{'name': 'Chromium PDF Viewer',
#   'description': 'Portable Document Format',
#   'filename': 'mhjfbmdgcfjbbpaeojofohoefgiehjai',
#   'mimeTypes': [{'type': 'application/pdf',
#                  'suffixes': 'pdf',
#                  'description': 'Portable Document Format'},
#                 {'type': 'text/pdf',
#                  'suffixes': 'pdf',
#                  'description': 'Portable Document Format'}]},
#  {'name': 'Native Client',
#   'description': 'native Client Execution',
#   'filename': 'internal-nacl-plugin'},
#  {'name': 'PDF Viewer',
#   'description': 'Portable Document Format',
#   'filename': 'oemmndcbldboiebfnladdacbdfmadadm',
#   'mimeTypes': [{'type': 'application/pdf',
#                  'suffixes': 'pdf',
#                  'description': 'Portable Document Format'},
#                 {'type': 'text/pdf',
#                  'suffixes': 'pdf',
#                  'description': 'Portable Document Format'}]}]
